# %%
ecommerce_kh ="""电商know-how V1
# 电商运营全场景核心关键点汇总（来源：电商素材.xlsx）
> 本次汇总覆盖电商企业交易合规、政策适配、主体规划、特殊业务处理、风险应对五大核心场景的所有关键规则，所有内容均来源于《电商素材.xlsx》，可直接作为企业合规运营、风险防控的参考依据。

---

## 一、交易全流程合规关键点
本模块涵盖电商日常交易场景的合规与涉税核心规则：
1. **刷单退货规则**：刷单收入可凭完整证据链（平台后台净销售额截图、刷单支出凭证、低于0.1kg的空包物流证明、资金回流记录等）从应税收入中剔除，但刷单本身属于虚假宣传行为，面临20-200万元市场监督管理局处罚、平台流量降权甚至清退的风险；真实退货可凭退款记录、入库单等在当期冲减收入，平台报送收入已包含退款额可直接申报减除。
2. **好评返现规则**：好评返现本质属于不正当竞争行为禁止直接实施，可替换为三类合规方案：不与评价挂钩的售后关怀金（按商业折扣冲减收入抵扣增值税）、会员积分（按递延收益分期确认收入）、新品试用（签订试用协议，视同销售申报增值税）。
3. **抽奖个税规则**：现金红包、实物奖品需按“偶然所得”缴纳20%个税，活动明示的优惠券/折扣券免征个税；可通过替换奖品类型、降低实物奖品价值（部分地区10元以下奖品可从宽征管）、选用平台通用红包递延纳税三类方式优化税负，申报需在兑奖次月15日内通过自然人电子税务局扣缴端完成。

## 二、平台报送与新政适配关键点
本模块涵盖2025年生效的互联网平台涉税报送新规的核心要求：
1. **核心规则**：新规要求商家全额确认收入，申报收入与平台数据存在差异即可能触发税务预警，无固定安全比例；新规本身不溯及既往，平台无需报送新规施行前的涉税信息，但偷税、抗税、骗税行为不受3-5年追征期限制，税务机关仍可核查历史违规行为。
2. **报送时间与内容**：2025年7月1-30日平台首次报送基本信息，10月1-31日首次报送经营者身份信息、收入信息、直播涉税信息，后续收入信息按季度报送；阿里国际站等跨境平台还需额外报送外汇、物流通关数据，符合跨境电商出口免税条件的交易需单独标注“跨境免税”标识。
3.**风险与应对**：平台报送收入无论结算至公户还是老板私人卡均属于监管范围，未申报将被认定为隐匿收入，面临0.5-5倍罚款；出现数据差异时可凭刷单、退货证据向税务机关说明，无法举证的需及时更正申报补税。

互联网平台涉税报送新规对电商经营者的影响：
1.经营收入全面透明化，告别信息不对称
平台向税务机关常态化报送数据，意味着电商经营者的实际经营状况已被纳入直接监管。平台需按季度报送销售收入、退款、净收入及交易详情，这使得过去依靠隐匿收入来降低税负的操作空间不复存在。
2.多平台数据归并，构建完整收入画像
税务机关能够通过技术手段，将同一经营者在不同电商平台甚至线下的收入进行合并计算。无论商家在几个平台经营，其总收入规模都会被完整呈现，有效防止了分散收入逃避监管的行为。
3.数据自动比对，触发风险预警机制
税务部门会将平台报送的数据与商家自行申报的数据进行自动比对。一旦发现申报收入明显低于平台报送的金额，系统会立即预警，轻则收到提示要求核实更正，重则可能面临税务稽查。
4.已登记但隐匿收入的商家税负回归正常
过去通过隐匿收入、虚假申报来减轻税负的商家，现在需要补上这部分成本。税负回归正常将直接压缩此类商家的利润空间，以往依赖信息不透明的经营模式难以为继。
5.刷单行为将带来真实的税务成本
平台报送的收入信息不会剔除虚假交易。这意味着商家需要为刷单产生的虚构流水缴纳增值税和所得税，导致实际税负远高于真实经营利润，虚假的交易量将转化为实实在在的成本。
6.供应链不规范的商家面临进项抵扣难题
许多中小商家依赖不开发票的低价货源。在一般纳税人身份下，若无法取得合规的进项发票来抵扣销项增值税，将面临全额承担高额税负的局面，这会严重侵蚀利润，倒逼其规范采购渠道。电商企业需要寻找能开具发票的供应商，该类供应商的定价可能会较高，从而影响企业商业安排及商务谈判。

如果多店铺绑定的是同一企业主体，那么税局会把平台上报的每家店铺的销售数据合并计算，合并计算后若超过500万标准，将会丧失小规模纳税人的身份。根据新增值税法及国家税务总局2026年第2号公告，超标当期立即生效按一般纳税人计税。

针对新政是否会追溯既往，根据《互联网平台企业涉税信息报送规定》第十二条规定，“平台内经营者和从业人员在本规定施行前的涉税信息，互联网平台企业不需要报送”，电商平台新规本身不溯及既往。但是，根据《中华人民共和国税收征管法》第五十二条规定，“因纳税人、扣缴义务人计算错误等失误，未缴或者少缴税款的，税务机关在三年内可以追征税款、滞纳金;有特殊情况的，追征期可以延长到五年。对偷税、抗税、骗税的，税务机关追征其未缴或者少缴的税款、滞纳金或者所骗取的税款，不受前款规定期限的限制”，税局仍有权对历史违规行为追溯核查。因此，虽然不能阻止税局核查历史数据，但是可以通过以下方式降低被检查的风险：
1.优化主体结构：成立新主体，将新发生的业务转移至新主体，隔离历史风险，注销清税难度低的主体；
2.立即停止违规行为：收入全额、如实申报，确保 “平台数据、银行流水、纳税申报” 三方一致。采购、费用凭票入账，建立完整证据链。
## 三、主体设立与税负规划关键点
本模块涵盖电商主体选择、架构搭建、税负优化的合规要求：
1. **主体变更与选择规则**：个人店无法直接换绑企业店，需注销后重新注册，原店铺信誉、销量无法继承，全流程耗时15-30天；业务量小的初创商家可选择个体户，有规模、团队或融资需求的商家建议选择有限公司，目前电商类个体户核定征收政策管控严格，多数地区已取消，部分地区电商类个体户会被要求转为查账征收。
2. **多主体运营合规要求**：多主体拆分需具备合理商业目的（按品牌/渠道/区域等进行拆分），做到业务独立、人员独立、财务独立，禁止三类恶意拆分情形：同一控制人设立多家经营范围高度同质化主体、注册空壳主体仅用于拆分收入、拆分合同至多个低优惠门槛主体，否则将被金税系统穿透联查，认定为偷税。
3. **税负优化风险与方案**：综合税负控制在2.5%以内的承诺均通过恶意拆分、虚开发票等不合规手段实现，风险极高；缺成本票可通过三类合规方式解决：合理拆分业务控制单主体年销售额在500万以内避免强制升为一般纳税人、优先选择可开票供应商、享受小微企业所得税等税收优惠。

针对维持小规模纳税人，企业可以通过以下方式：
1.建立连续12个月销售额台账，逐月/逐季度核算，临近450万元时进行预警；
2.按品类、品牌、渠道拆分至多个独立主体（个体户/小规模公司），拆分时建议参照拆分过程需要注意国家税务总局政策法规司《小微企业套享税收优惠政策问题即问即答》对于分拆收入的要求列举了正面及负面清单，避免“一址多证”、人员混同、空壳公司无实质经营、资产共用、各主体收入与其实际业务匹配等情况；
3.合理控制广告投放、大促规模，避免单月/季度集中冲高导致滚动超标；
4.明确平台费用，佣金、技术服务费等不计入应税销售额；
5.留存刷单、退货、退款凭证，及时冲减销售额。
## 四、特殊业务处理关键点
本模块涵盖电商两类高频特殊业务的标准化税务处理规则：
1.**平台补贴处理**：价格补贴（平台直接补贴消费者降低成交价）属于商品销售收入组成部分，一般纳税人按13%税率开具货物发票给平台；推广服务费补贴（平台支付给商家的流量扶持）签订服务协议明确业务实质后，可按6%税率开具服务费发票给平台。但是各地税局的征管口径不一致，需要与主管税局确认。
2. **一件代发快递费处理**：厂家身份收取的快递费需并入商品全部价款，按销售货物计税（一般纳税人13%、小规模1%/3%），不得单独开具快递费发票；承担运输风险的中间承运人按物流辅助服务开具快递费发票；不承担运输风险的中间方仅就收取的差价按经纪代理服务开票，快递费发票由物流公司直接开具给收货方。

## 五、税务自查与风险应对关键点
本模块涵盖电商企业面临税务自查时的标准化应对方案：
1. **收入端核减**：凭完整证据链剔除刷单、线下退货收入，按收入确认准则调整跨期、预售订单的收入确认期间，降低应税收入基数。
2. **成本端补足**：要求供应商、平台补开成本费用发票，补报账外支付的工资并利用个税专项附加扣除、年终奖单独计税等政策增加税前列支，将基础软件服务费从广宣费调整至技术服务费避免受15%/30%扣除限额限制，集团内可通过广宣费分摊协议调剂扣除额度。
3.**优惠政策适用**：存在增值税留抵税额的可申请抵减增值税欠税及对应滞纳金，全额适用小规模免征、小微企业所得税优惠、跨境电商免税等政策降低税负。
4.**电商行业税务监管特点**：
电商是一种商业模式的总称，因地域、商品、经营模式不同，没有统一的固定的行业税负。红线是多维度的，同样，根据地域不同、商品类别不同、监管重点不同，没有统一不变的指标阈值。税务监管的指标红线是多维度的，同样，根据地域不同、商品类别不同、监管重点不同，没有统一不变的指标阈值。
当前可以明确的是，电商企业已经收到的税务风险推送中，包括以下高频的风险预警事项，企业应当对照自查，避免触及同样的风险：企业申报销售收入低于平台企业报送其收入全额；企业进销项税额倒挂，货物进项和服务费进项大于销项；企业退货金额或占比异常（过高或过低）；企业申报销售收入与购进货物不匹配；未开票收入金额或占比过低；平台服务费、快递费等占比过高；企业申报销售收入与线上服务费不匹配

### 电商行业高频特殊业务处理指引（来源：电商素材.xlsx）

以下内容均匹配当前电商行业实操规则与最新政策要求，可直接纳入培训手册使用：

---

#### 一、刷单账务及税务处理
**政策依据**：《互联网平台企业涉税信息报送规定》、《反不正当竞争法》
##### 账务处理流程
刷单的“收入”，属于虚构交易、无真实货物流转与经济利益流入，不应确认为主营业务收入，应按资金往来处理。当将资金打给员工或刷手用于支付时，应借记“其他应收款”、贷记“银行存款”；当刷单资金通过平台回款至公司账户时，由于这本质上是需返还的本金而非收入，应借记“银行存款”、贷记“其他应付款”，最后将“其他应付款”对冲“其他应收款”。对于商家支付的刷单佣金、手续费、空包物流等费用通常计入销售费用。根据企业所得税法，这些支出因具有市场营销属性，与获取收入存在关联，理论上属于可税前扣除的合理支出。然而实际操作中面临障碍，核心在于刷单行为本身的违规性导致支出难以取得正规发票等合法有效凭证，使得企业在所得税申报时扣除受限。需要厘清的是，刷单的违规性属于市场监管和平台规则层面的问题，而税法对支出的认定更侧重于经济实质，从法理上讲，行政违规性不应自动否定其税前扣除资格。因此，企业在经营中应当规范财务处理，避免因刷单行为引发重大税务风险。
在实务中，由于平台结算和刷单结算存在时间差，大部分电商公司的操作是先按平台结算单入账，后续核对刷单结算单后红冲；部分大量刷单可能会通过供应链提供的物料数据暂估，后红冲。
##### 税务处理流程
1. **收入端判定**：刷单属于虚假交易，原则上不产生纳税义务，但平台默认报送全量订单收入，需由商家自行举证剔除。
2. **举证要求**：需提供完整证据链，包括：①平台后台净销售额截图（标注异常订单）；②刷单相关协议、资金流水（含支付给刷手的佣金记录、资金回流凭证）；③物流证明（快递公司盖章的空包/低重量物流清单、无实际配送记录凭证）；④内部刷单台账、组织聊天记录等。
3. **申报调整**：若能提供完整证据链，可在纳税申报时从销售额中剔除刷单金额；无法举证的，需按正常交易申报缴纳增值税及企业所得税。
4. **费用端处理**：刷单产生的佣金、物流费等支出，因具有市场营销属性，与获取收入存在关联，理论上属于可税前扣除的合理支出，若能提供真实凭证可据实入账；无法证明真实性的，不得在企业所得税税前扣除。具体扣除口径应以主管税务监管要求为准。

##### 高频风险提示
1. 刷单本身违反《反不正当竞争法》，可处20万-200万元罚款，情节严重的吊销营业执照，证明刷单虽可减少税负但可能触发市监处罚，需提前测算风险成本。建议测算两边的违法成本，再确定是否刨除刷单收入。
2. 若无法提供完整证据链，税务机关将直接认定刷单金额为应税收入，需按13%（一般纳税人）/1%-3%（小规模）补缴增值税，按5%/25%补缴企业所得税，并加收每日万分之五的滞纳金及0.5-5倍罚款。

---

#### 二、平台补贴计税处理
**政策依据**：增值税暂行条例、发票管理办法
##### 处理流程
1. **性质判定与计税规则**
   - 若补贴属于**价格补贴**（如平台直接补贴消费者降低成交价，如百亿补贴、消费者领取的平台优惠券），属于商品销售收入的组成部分，一般纳税人按13%税率开具货物类发票，计入主营业务收入申报纳税。
   - 若补贴属于**推广服务费**（如平台支付给商家用于流量扶持、活动专项奖励），需签订服务协议明确业务实质，可按6%税率开具服务类发票，计入其他业务收入或主营业务收入申报。但是各地税局的征管口径不一致，需要与主管税局确认。
2. **申报要求**：平台补贴收入需全额计入应税收入申报，不得直接从平台报送的收入总额中扣除。

##### 高频风险提示
1. 不得随意变更发票税目，未明确业务实质的情况下开具6%服务费发票可能被认定为虚开发票。
2. 补贴收入若未如实申报，将触发平台报送数据与申报数据差异预警，需补缴税款及滞纳金。

---

#### 三、退换货成本核算及税务处理
**政策依据**：《企业会计准则第14号——收入》、增值税暂行条例实施细则
##### 处理流程
1. **收入冲减规则**：真实发生的退换货，可在退货当期冲减对应销售收入；平台报送数据已包含退款金额的，申报时可直接减除线上留痕的退款金额。
2. **线下退货举证要求**：若为协商后的线下退货（未走平台退款流程），需提供证据链包括：①对应订单的退款资金流水记录；②退货物流单、仓库入库验收记录；③与消费者的沟通记录、退货协议等，凭上述凭证冲减当期收入。
3. **成本核算**：退换货产生的物流费、商品损耗费等，计入当期销售费用，取得合法凭证的可在企业所得税税前扣除；退回商品已发生减值、无法二次销售的，按资产损失相关规定申报扣除。
4. **跨期退货处理**：若退货发生在收入确认当年汇算清缴前，可调整报告年度收入成本；发生在汇算清缴后的，计入退货当期损益。

##### 高频风险提示
1. 无合理凭证的线下退货不得自行冲减收入，否则将导致申报数据低于平台报送数据，触发税务预警。
2.虚构退货业务冲减收入的，将被认定为隐匿收入，需补缴税款、滞纳金并处0.5-5倍罚款。 

"""

# %%
import json5
import json
with open("./ecommerce_orientation_know_how.json") as e:
    ecommerce_kh_mapreduce = json.load(e)
    
ecommerce_kh_mapreduce = {k:v['content'] for k,v in ecommerce_kh_mapreduce.items()}
kh_index = {i:list(ecommerce_kh_mapreduce.keys())[i] for i in range(len(ecommerce_kh_mapreduce.items()))}
# ecommerce_kh_mapreduce

# %%
import os
import time
import functools
from openai import OpenAI
from dotenv import load_dotenv
import traceback
import requests
import json

def retry(max_retries: int = 5, sleep_seconds: float = 15.0):
    """
    重试装饰器：函数报错时等待 sleep_seconds 秒后重试，最多重试 max_retries 次。
    超过重试上限后，抛出最后一次的异常。
    """
    def decorator(func):
        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            last_exc = None
            for attempt in range(1, max_retries + 2):  # 1次正常 + max_retries次重试
                try:
                    return func(*args, **kwargs)
                except Exception as e:
                    last_exc = e
                    if attempt <= max_retries:
                        print(f"[retry] {func.__name__} 第{attempt}次失败: {traceback.format_exc()}，{sleep_seconds}秒后重试...")
                        time.sleep(sleep_seconds)
                    else:
                        print(f"[retry] {func.__name__} 已达最大重试次数({max_retries})，放弃。")
            raise last_exc
        return wrapper
    return decorator


@retry(max_retries=3, sleep_seconds=5.0)
def qwen(prompt, web_search: bool = False, enable_thinking: bool = False):
    client = OpenAI(
        # 从环境变量读取，或直接填写 api_key="sk-xxx"
        api_key="sk-fb07e345e2b04562ad5acf2d4bfee8fa", #os.getenv("QWEN_API_KEY"),
        # 北京地域（默认）
        base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"

    )

    completion = client.chat.completions.create(
        model=os.getenv("INFER_LLM_NAME", "qwen3-max"),
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        # stream=True,  # 如需流式输出，取消注释
        extra_body={
            "enable_search": web_search,  # 开启联网搜索
            "enable_thinking": enable_thinking,  # 开关思考功能
            # "thinking_budget": 81920   # 可选：限制思考过程最大Token数（默认32768）
            # "search_options": {
            #     "forced_search": True,        # 强制开启搜索（默认false，由模型判断是否使用）
            #     "search_strategy": "turbo",   # 搜索策略：turbo(默认)/max/agent/agent_max
            #     "enable_source": True,        # 返回搜索结果来源（仅部分模型支持）
            #     "enable_citation": True,      # 开启角标标注[1]样式（需enable_source为true）
            #     "citation_format": "[ref_<number>]"  # 角标样式：[<number>] 或 [ref_<number>]
            # }
        }

    )
    if enable_thinking:
        res ={
            "content": completion.choices[0].message.content,
            "reasoning_content":completion.choices[0].message.reasoning_content
        }
    else:
        res ={
            "content": completion.choices[0].message.content,
            "reasoning_content":""
        }

    return res

# %%
#"sk-5a5c8fea7cc14d779a201d8ab0be8f91"

@retry(max_retries=3, sleep_seconds=5.0)
def chat(messages: str, vendor: str = "volc", model: str = "deepseek-v3.2") -> str:
    if vendor == "servyou":
        URL = f"http://10.199.0.7:5000/api/llm/{vendor}/v1/chat/completions"
        app_id = "sk-d75b519b704d4d348245efe435f08ff3"
    else:
        URL = f"http://mlp.paas.dc.servyou-it.com/mudgate/api/llm/{vendor}/v1/chat/completions"
        app_id = "sk-0609aa6d08de4413a72e14b3fb8fbab1"
        
    HEADERS = {"Content-Type": "application/json", "Authorization": app_id}
    messages = [{"role": "user", "content": messages}]
    PAYLOAD = {
        "appId": app_id,
        "model": model,
        "messages": messages,
        "stream": False,
        "top_p": 0.7,
        "temperature": 0.5,
        # "enable_thinking": True,
        # "enable_search":True
    }
    response = requests.post(URL, data=json.dumps(PAYLOAD), headers=HEADERS).json()
    if "success" in response:
        raise Exception(response["errorContext"])
    return response["choices"][0]["message"]#["content"]

# %%
import pandas as pd
from tqdm import tqdm

# %%
test_data = pd.read_excel("./ecommerce.csv")

# %%
test_data.shape
# Out:
# (10, 16)

# %%
prompt = """# Role
你是一位专业的电商行业财税领域专家，擅长基于[电商行业Know-How]对[用户的问题]进行细致严谨的回答

## 电商行业Know-How
{}

## 用户的问题
{}

请开始："""

# %%
prompt_pure_llm = """# Role
你是一位专业的电商行业财税领域专家，擅长基于你的专业能力对[用户的问题]进行细致严谨的回答

## 用户的问题
{}

请你先细致思考，再得出最终的结论："""

# %%
prompt_simple_with_kh = """# Role
你是一位专业的财税实务领域专家，擅长基于[实务经验答案]、[第三方知识答案]、[缺陷答案]，对[用户的问题]进行严谨的回答

## 实务经验答案
{}

## 第三方知识答案
{}

## 缺陷答案
{}
 
## 用户的问题
{}

### 思考流程
1. 观察[实务经验答案]内容是否有直接可以解答[用户的问题]的方法论和经验，得出初步结论
2. 观察[第三方知识答案]中是否有能够支撑初步结论的知识，若有则补充关键要点
3. 观察[缺陷答案]是否能够支撑初步结论，若能支撑则酌情补充知识；若冲突则忽略该[缺陷答案]
4. 检查步骤1、2、3是否指向同一个结论，并整合给出精简又准确的完美回答

### 注意事项
- 知识参考的优先级：[实务经验答案] > [第三方知识答案] > [缺陷答案]
- 最终的回答里，请你先给出核心结论，再给出汇总的关键要点
- 回答必须保持在300字以内！

请开始："""

# %%
kh_selection = """# Role
你是一位专业的电商行业财税领域专家，擅长从 `<Knowledge_Menu>` 中挑选对 `<User_Question>` 有关的目录序号

# Input Data
<Knowledge_Menu>
0: '第1章 电商行业全景透视',
1: '1.3电商行业参与者',
2: '1.1电商行业发展现状与趋势',
3: '1.2电商商业模式解析',
4: '1.1.1国内电商市场格局',
5: '1.1.2跨境电商发展态势',
6: '1.1.3社交电商/直播电商等新兴模式',
7: '1.2.2平台运营双模式',
8: '1.2.3电商创新经营形态',
9: '1.3.2商家/厂家运营模式',
10: '2.1消费者权益保护与交易规范',
11: '第2章电商行业政策框架',
12: '1.2.1电商不同模式解析',
13: '1.3.1平台公司及盈利方式',
14: '2.2平台运营合规与监管制度建设',
15: '2.1.1《网络反不正当竞争暂行规定》',
16: '2.2.1《电子商务法》',
17: '2.1.3《网络购买商品七日无理由退货暂行办法》',
18: '2.2.2《网络交易监督管理办法》',
19: '2.2.3《自然人网店管理规范》',
20: '2.1.2《消费者权益保护法实施条例》',
21: '2.3.1《网络交易合规数据报送管理暂行办法》',
22: '1.3.3 MCN机构/主播财税处理',
23: '2.3.2《网络直播营利行为规范意见》',
24: '2.3新兴业态监管制度建设',
25: '3.1.1商品控制权转移的判定标准',
26: '2.3.3 《互联网平台企业涉税信息报送规定》',
27: '3.1收入确认原则',
28: '第3章 收入确认与财税处理',
29: '4.1采购成本处理',
30: '第4章 成本费用管理',
31: '3.1.3多平台收入合并处理',
32: '3.1.2电商收入确认财税处理',
33: '3.2特殊交易处理',
34: '3.2.1七天无理由退货的财税处理',
35: '3.3.1秒杀活动/平台积分的财税处理',
36: '3.3.2抽奖/福袋的税务处理',
37: '3.2.2跨店满减/店铺积分的财税处理',
38: '3.3.3线上团购/好评返现合规',
39: '3.3促销活动处理',
40: '3.2.3预售制收入确认方法',
41: '4.1.2库存账实不符解决方案',
42: '4.2营销费用处理',
43: '4.1.1无票采购的应对策略',
44: '4.1.3购销背离风险防控',
45: '4.2.2销售分成费用',
46: '第5章 电商行业典型财税风险',
47: '4.3其他费用管理',
48: '4.3.1物流费用优化方案',
49: '5.1收入端风险',
50: '4.3.2灵活用工成本处理',
51: '4.2.1线上推广费用',
52: '5.2成本端风险',
53: '4.2.3市场活动费用',
54: '4.3.3售后（退货）成本管控',
55: '5.1.2私户收款隐匿收入',
56: '5.2.1成本票缺失问题',
57: '5.1.1刷单虚增收入风险',
58: '5.2.2虚开发票风险识别',
59: '5.2.3关联交易定价风险',
60: '5.1.3收入确认不当风险',
61: '5.3.1第三方支付风险',
62: '5.3资金管理风险',
63: '第6章 税务稽查应对',
64: '6.1 高风险领域预警',
65: '5.3.2运营资金风险',
66: '6.1.2 GMV与申报收入差异分析',
67: '7.1 电商主体规划策略',
68: '6.2.1电商企业税务稽查现状\u200b ',
69: '第7章 电商企业的合规节税策略',
70: '6.1.1电商企业被税务稽查的原因\u200b ',
71: '6.2 电商企业应对税务稽查的策略\u200b ',
72: '5.3.3债务与融资风险',
73: '6.1.4金税四期监控重点',
74: '6.1.3平台数据与税务申报比对',
75: '6.2.5电商企业应对税务稽查的策略',
76: '6.2.2电商企业税务稽查常见问题解析\u200b ',
77: '6.2.3收到税务自查通知书的应对',
78: '6.2.4税务稽查的数据来源',
79: '7.1.1电商企业的分类',
80: '7.1.2常见电商店铺入驻企业的主体形式\u200b ',
81: '7.1.6电商企业在税收洼地注册的选择策略',
82: '7.2 业务架构优化策略',
83: '7.2.2电商企业的交易流程再造',
84: '7.2.3供应链成本优化',
85: '7.1.4电商企业的主体形式选择策略\u200b ',
86: '7.3 资金管理优化',
87: '7.2.1电商店群企业的架构搭建',
88: '7.1.5多平台店铺绑定主体业务分拆策略',
89: '7.1.3不同主体形式税务差异分析\u200b ',
90: '7.3.1公账私账分离方案',
91: '第8章 国内电商案例',
92: '8.1 直播电商案例',
93: '7.3.2第三方支付规范',
94: '8.1.2直播电商典型成功案例财税分析\u200b ',
95: '8.1.3直播电商典型失败案例财税分析\u200b ',
96: '8.2 平台商家案例',
97: '8.2.1电商平台在财税管理中的角色与责任\u200b ',
98: '8.1.1直播电商涉及的主要财税政策\u200b ',
99: '8.3.1电商分销模式的定义与分类\u200b ',
100: '8.2.3多店铺账务合并案例分析',
101: '8.2.2成功解决财税问题的电商平台商家案例分析\u200b ',
102: '8.3.2电商分销模式的运作流程\u200b ',
103: '8.2.4电商刷单数据调整',
104: '8.3 分销模式案例',
105: '8.3.3电商分销模式的优势与挑战\u200b ',
106: '8.3.4一件代发税务处理案例分析\u200b ',
107: '8.3.5分销商发票管理案例分析\u200b '
</Knowledge_Menu>

<User_Question>
{}
</User_Question>

# Rules
## Attention
- 请你思考 `<Knowledge_Menu>` 中目录名称跟 `<User_Question>` 的相关程度，严谨地选择对应目录序号。
- 请你严格遵循 Output Format 下的输出样例进行输出

## Output Format
以下是输出样例，请你保证你输出的JSON能够被json.loads直接解析，不要包含 ```JSON 和 ``` 这些字符串
```JSON
{{
    "reasoning": "str // 你对各目录名称与 `<User_Question>` 相关性的思考"
    "menu_index": "List[int] // 你从 `<Knowledge_Menu>` 中选择的所有目录序号，数量保持在5个以内" 
}},
```

开始输出"""

# %% [raw]
# import concurrent.futures
# from tqdm import tqdm
# import time
#
# # 1. 定义单个任务的执行函数 (包含重试机制，防止网络波动导致中断)
# def process_single_question(index, q, prompt_template, kb_context, max_retries=3):
#     """
#     处理单个问题，返回 (原始索引, 结果字符串)
#     """
#     formatted_prompt = prompt_template.format(kb_context,q)
#
#     for attempt in range(max_retries):
#         try:
#             # 调用大模型并提取 content
#             res = chat(formatted_prompt, "servyou", "qwen-32b")["content"]
#             return index, res
#         except Exception as e:
#             if attempt < max_retries - 1:
#                 time.sleep(2 ** attempt) # 失败则等待 1s, 2s, 4s 后重试
#             else:
#                 error_msg = f"[Error] 提取失败: {str(e)}"
#                 return index, error_msg # 多次重试失败后返回错误信息，防止程序崩溃
#
# # 2. 多线程执行主逻辑
# WORKERS = 16  # 根据你的 API 账号并发限制进行调整 (如 OpenAI/阿里建议 3-10)
#
# print(f"启动多线程处理，并发数: {WORKERS}...")
#
# # 预先分配一个长度等于测试集大小的列表，用于占位，保证最终顺序与 test_data 一致
# ans = [None] * len(test_data)
#
# with concurrent.futures.ThreadPoolExecutor(max_workers=WORKERS) as executor:
#     # 提交所有任务，并将 future 与其对应的索引绑定
#     future_to_index = {
#         executor.submit(
#             process_single_question,
#             index=i,
#             q=test_data.loc[i, '问题内容'],
#             prompt_template=prompt_simple_with_kh,
#             kb_context=ecommerce_kh
#         ): i
#         for i in range(len(test_data))
#     }
#
#     # 使用 as_completed 结合 tqdm 动态显示进度
#     for future in tqdm(concurrent.futures.as_completed(future_to_index),
#                        total=len(test_data),
#                        desc="Processing QA"):
#         # 获取结果 (返回的是 原始索引 和 生成的内容)
#         index, res = future.result()
#
#         # 按原始索引放入列表，绝对保证顺序不乱！
#         ans[index] = res
#
#         # 实时打印最新完成的结果 (如果觉得打印太长，可以改为 print(res[:50] + "...") 截断显示)
#         print(f"\n[已完成 Row {index}] => {res}")
#
# print("\n🎉 所有问题处理完成！")
# # 现在你可以放心地把 ans 加回 dataframe 了，例如：
# # test_data['模型回答'] = ans

# %%
import concurrent.futures
from tqdm import tqdm
import time
import os
import json

# --- 配置文件路径 ---
CHECKPOINT_FILE = "qa_results_checkpoint.jsonl"

def process_single_question(index, q, prompt_template, kb_context, max_retries=10):
    kh_selection_prompt = kh_selection.format(q)
    
    # QAknow-how mapreduce（严密逻辑，不能漏）
    
    # 电商指南知识筛选 （宽松逻辑，锦上添花）
    for attempt in range(max_retries):
        try:
            selection_res = chat(kh_selection_prompt)["content"].lower().strip().strip("```").strip("json")
            print(selection_res)
            selection_index = [int(i) for i in json5.loads(selection_res)['menu_index']]
            selection_kh_block = "\n\n".join([ecommerce_kh_mapreduce[kh_index[i]] for i in selection_index])
            print(selection_kh_block)
            break
        except Exception as e:
            if attempt < max_retries - 1:
                time.sleep(3)
            else:
                return index, f"知识筛选[Error] {str(e)}"
            
    # 原生能力推理 （宽松逻辑，锦上添花）
            
    # 知识推理
    infer_prompt = prompt_template.format(kb_context, selection_kh_block, q)
    print(len(infer_prompt))
    for attempt in range(max_retries):
        try:
            res = chat(infer_prompt)["content"]
            return index, res
        except Exception as e:
            if attempt < max_retries - 1:
                time.sleep(3)
            else:
                return index, f"知识推理[Error] {str(e)}"

# 1. 加载已经完成的进度
def load_checkpoints():
    completed_results = {}
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, 'r', encoding='utf-8') as f:
            for line in f:
                data = json.loads(line)
                completed_results[data['index']] = data['res']
    return completed_results

# 2. 主逻辑
completed_data = load_checkpoints()
print(f"检测到已完成 {len(completed_data)} 条记录，准备继续未完成的任务...")

WORKERS = 16
ans = [None] * len(test_data)

# 先把已有的结果填入 ans 列表
for idx, res in completed_data.items():
    if idx < len(ans):
        ans[idx] = res

with concurrent.futures.ThreadPoolExecutor(max_workers=WORKERS) as executor:
    # 3. 只提交【不在已完成列表里】的任务
    future_to_index = {
        executor.submit(
            process_single_question, 
            index=i, 
            q=test_data.iloc[i]['问题内容'], 
            prompt_template=prompt_simple_with_kh, 
            kb_context=ecommerce_kh
        ): i for i in range(len(test_data)) if i not in completed_data  # 关键：过滤已完成项
    }
    
    # 如果没有新任务需要处理
    if not future_to_index:
        print("所有任务已完成，无需运行。")
    else:
        with open(CHECKPOINT_FILE, 'a', encoding='utf-8') as f: # 使用 append 模式实时写入
            pbar = tqdm(concurrent.futures.as_completed(future_to_index), 
                        total=len(future_to_index), 
                        desc="断点续传处理中")
            
            for future in pbar:
                index, res = future.result()
                ans[index] = res
                
                # 4. 每完成一条，立即写入本地文件（防止崩溃）
                checkpoint_entry = {"index": index, "res": res}
                f.write(json.dumps(checkpoint_entry, ensure_ascii=False) + "\n")
                f.flush() # 强制刷新缓冲区，确保写入硬盘
                
                pbar.set_postfix_str(f"Row {index} saved")

# 5. 最后合并回 DataFrame
test_data['模型回答'] = ans
# 如果需要，可以将最终结果保存并删除 checkpoint 文件
# test_data.to_excel("final_results.xlsx", index=False)
# os.remove(CHECKPOINT_FILE) 

print("\n🎉 任务全部处理完成！")
# Out:
# 检测到已完成 0 条记录，准备继续未完成的任务...
# 断点续传处理中:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#     "reasoning": "用户问题聚焦于电商平台报数新规实施后，小规模纳税人资格的维持。这主要涉及税务合规、数据报送与主体资格管理。首先，新规的核心是平台数据向税务部门报送，因此与“平台数据与税务申报比对”(74)、“金税四期监控重点”(73)直接相关。其次，资格维持属于企业主体规划与合规策略范畴，涉及“电商企业的主体形式选择策略”(85)、“不同主体形式税务差异分析”(89)。再者，新规实施后，企业需应对稽查风险，故“电商企业被税务稽查的原因”(70)、“电商企业应对税务稽查的策略”(71)相关。最后，问题隐含收入确认、私户收款等常见影响资格的风险点，因此“收入确认不当风险”(60)、“私户收款隐匿收入”(55)也需考虑。",
#     "menu_index": [74, 73, 85, 89, 70, 71, 60, 55, 26, 21]
# }
#
# {
#   "Logic_Diagnosis": "该段落详细讲解了电商企业在税务申报中的数据比对、合规措施及存在的问题，已泛化为适用于电商行业的通用税务合规准则。",
#   "Know_How": "### 电商行业税务合规与数据比对准则\n- **核心逻辑解析**：电商企业需建立健全财务核算体系，确保收入确认和成本费用核算的准确性和规范性。税务风险管理应包括设立税务管理岗位、定期评估税务风险、监控税务申报流程。提升员工财税专业素养，确保财税政策的理解和执行。电商平台数据与税务申报比对是关键，涉及数据指标比对、数据来源与获取方式、比对方法与技术。比对过程中需关注数据准确性与完整性、税收政策理解与执行差异、电商平台与税务机关的协作障碍。\n- **适用范畴**：适用于所有涉及电商交易的企业，尤其是需要进行税务申报的电商企业。\n- **政策/理论依据**：《网络交易合规数据报送管理暂行办法》（自2025年4月25日起施行），涉及增值税、企业所得税、个人所得税等税种的申报要求。"
# }
#
# {
# ...

# %%
ans
# Out:
# ['平台向税务报送数据，将使电商经营者的收入全面透明化，告别信息不对称时代。具体影响如下：\n\n1.  **收入全面监管**：平台按季度报送您的销售收入、退款及交易详情，税务机关能直接掌握真实经营数据。\n2.  **多平台数据合并**：税局可将您在不同平台（如淘宝、抖音、京东）的收入合并计算，构建完整的收入画像，防止通过分散收入逃避监管。\n3.  **自动比对预警**：系统会自动比对平台报送数据与您自行申报的数据。一旦申报收入明显偏低，会立即触发税务风险预警，可能面临补税、罚款及滞纳金。\n4.  **刷单产生真实税负**：平台报送的是全量订单流水，包含刷单等虚假交易。若无法提供完整证据链举证剔除，您需为这部分虚构流水缴纳增值税和所得税。\n5.  **倒逼供应链规范**：收入透明后，若您是一般纳税人但无法从供应商处取得合规进项发票，将面临高额增值税税负，利润被严重侵蚀，从而被迫规范采购渠道。',
#  '对于多平台多店铺经营的电商老板，新规带来的核心风险是**收入全面透明化与强制合并计税**。\n\n1.  **收入合并风险**：所有平台店铺收入（无论结算至公户或私卡）均会被平台报送并汇总。若多个店铺绑定同一企业主体，合并收入极易超过500万小规模纳税人标准，导致**强制转为一般纳税人**，税负显著上升。\n2.  **数据比对预警风险**：税务机关将自动比对平台报送总收入与你申报的收入。**任何差异**（如未申报的刷单、线下退货）都可能触发税务预警，若无法提供完整证据链（如刷单资金回流、物流证明），差异部分将被认定为隐匿收入，面临补税、滞纳金及0.5-5倍罚款。\n3.  **恶意拆分稽查风险**：为避税设立多个空壳主体、人为拆分收入，一旦被金税系统通过“一址多证”、人员混同等线索穿透识别，将被认定为偷税，风险极高。\n\n**应对核心**：确保各主体业务独立合规，做到“平台数据、银行流水、纳税申报”三方一致，对刷单等差异留存完整证据链备查。',
# ...

# %%
test_data['模型回答（指南+行业know-how-ds）'] = ans

# %%
test_data.to_excel("./ecommerce_test_with_kh_simple_result_0320.xlsx")
